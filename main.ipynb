# %%
import sys
import pandas as pd

# %% [markdown]
# # Load Data

# %%
print(sys.path[0])
# Out:
# c:\Users\신아현\Desktop\ahshin\project\job_recruit_recommendation

# %%
app_df = pd.read_csv(sys.path[0]+'/data/apply_train.csv')  # 이력서가 채용 공고에 실제 지원한 관계 목록 (히스토리)
com_df = pd.read_csv(sys.path[0]+'/data/company.csv')  # 채용공고 관련 데이터
rec_df = pd.read_csv(sys.path[0]+'/data/recruitment.csv')  # 채용공고 관련 데이터
res_cer_df = pd.read_csv(sys.path[0]+'/data/resume_certificate.csv')  # 이력서 관련 데이터
res_edu_df = pd.read_csv(sys.path[0]+'/data/resume_education.csv')  # 이력서 관련 데이터
res_lan_df = pd.read_csv(sys.path[0]+'/data/resume_language.csv')  # 이력서 관련 데이터
res_df = pd.read_csv(sys.path[0]+'/data/resume.csv')  # 이력서 관련 데이터
sam_df = pd.read_csv(sys.path[0]+'/data/sample_submission.csv')

# %%
com_df
# Out:
#      recruitment_seq  company_type_seq  supply_kind  employee
# 0             R02073                 2          514        20
# 1             R03274                 2          402        90
# 2             R02195                 2          514        20
# 3             R03372                 4          100        60
# 4             R00867                 2          402       590
# ...              ...               ...          ...       ...
# 2372          R01786                 2          100       100
# 2373          R03415                 2          100       270
# 2374          R04028                 4          402       525
# 2375          R06508                 2          402        70
# 2376          R00604                 5          402       300
#
# [2377 rows x 4 columns]

# %%
rec_df
rec_df['text_keyword'].unique()
# Out:
# array([nan,
#        '해외영업;의류;품질관리;상품기획;머천다이저;자재관리;포토샵;생산관리;자재구매;여성복;일러스트레이터;구매관리;일반영업',
#        'MD;기획MD;여성복;캐주얼', '소재디자이너', '디자이너;여성복', '여성복MD', '디자인실;잇미샤',
#        '영업;대리점', '백화점영업;아웃도어영업', '상품기획', '의류;매장관리;섬유;백화점영업;영업;의류영업;영업관리',
#        '의류;의상;섬유;의복', 'DISCOVERY;아웃도어;생산관리', '비엔엑스;BNX;MD;영업MD',
#        'MD;기획MD;시선인터내셔널;잇미샤;ITMICHAA;여성패션;패션', '남성복;피팅모델;남성복MD',
#        'DISCOVERY;유통MD팀', '영업MD', '스타일디자인(피팅)', '여성의류;디자이너;캐주얼',
#        '에프앤에프;MD;디스커버리', '영업MD;인턴;MD;TANKUS;탱커스',
#        '거래처관리;매장관리;섬유;의류판매;영업관리', '해외바잉MD', '기획MD',
#        '의류;골프웨어;캐주얼;영업;아웃도어;스포츠웨어', '백화점;매장관리;매출관리;영업',
#        '임가공;입출고);자재관리;생산원가;원부자재;업무;핸드링;운전;공장;생산(완사입;관리(발주;상품입출고;산출',
#        '니트디자인', 'MD;여성복;기획', '에프앤에프;MLB;소재', '상품기획MD;기획MD;골프웨어MD',
#        '영업;여성복;패션', '영업관리', 'TECHNICAL;디자이너;테크니컬;DESIGNER;TD',
#        '상품기획;상품MD;MD;PAT;여성복MD', '디자이너;여성복;여성복디자이너', 'VMD;마케팅',
#        '상품기획;우븐;코오롱;생산MD', '위비스;신입;스포츠;디자이너;여성복;아웃도어;지센',
# ...
